# %% [markdown]
# # CS-6570 Lecture 5 - Data Wrangling
#
# **Dylan Zwick**
#
# *Weber State University*

# %% [markdown]
# Today, we're going to go over a few more features and functions that Pandas offers for manipulating and exploring data - sometimes called "Data Wrangling".

# %% [markdown]
# To do this, let's load up some data. We'll use the fortune500 dataset from Lecture 2.

# %%
import numpy as np
import pandas as pd

# %%
fortune500_df = pd.read_csv('Datasets/fortune500.csv')
fortune500_df.columns = ['year', 'rank', 'company', 'revenue', 'profit']
fortune500_df
# Out:
#        year  rank                company  revenue profit
# 0      1955     1         General Motors   9823.5    806
# 1      1955     2            Exxon Mobil   5661.4  584.8
# 2      1955     3             U.S. Steel   3250.4  195.4
# 3      1955     4       General Electric   2959.1  212.6
# 4      1955     5                 Esmark   2510.8   19.1
# ...     ...   ...                    ...      ...    ...
# 25495  2005   496        Wm. Wrigley Jr.   3648.6    493
# 25496  2005   497         Peabody Energy   3631.6  175.4
# 25497  2005   498  Wendy's International   3630.4   57.8
# 25498  2005   499     Kindred Healthcare   3616.6   70.6
# 25499  2005   500   Cincinnati Financial   3614.0    584
#
# [25500 rows x 5 columns]

# %% [markdown]
# We'll start by dropping any row that contains an N.A. for profit. You can check Lecture 2 for specifics of how we did this for this dataframe.
#
# Rob: This gives the rows that don't contain numberish characters and then we look for the inverse of that with the ~ operator to get the rows that are still good. This provides a boolean mask that contain true/false values.

# %%
non_numeric_profits = fortune500_df.profit.str.contains('[^0-9.-]')
fortune500_df = fortune500_df.loc[~non_numeric_profits]
# Including the ~ gives the not [true]
fortune500_df
# Out:
#        year  rank                company  revenue profit
# 0      1955     1         General Motors   9823.5    806
# 1      1955     2            Exxon Mobil   5661.4  584.8
# 2      1955     3             U.S. Steel   3250.4  195.4
# 3      1955     4       General Electric   2959.1  212.6
# 4      1955     5                 Esmark   2510.8   19.1
# ...     ...   ...                    ...      ...    ...
# 25495  2005   496        Wm. Wrigley Jr.   3648.6    493
# 25496  2005   497         Peabody Energy   3631.6  175.4
# 25497  2005   498  Wendy's International   3630.4   57.8
# 25498  2005   499     Kindred Healthcare   3616.6   70.6
# 25499  2005   500   Cincinnati Financial   3614.0    584
#
# [25131 rows x 5 columns]

# %% [markdown]
# We note that there are now 25,131 rows, but the index still goes from 0 to 25499. In other words, the index is no longer sequential, but contains gaps.
#
# If we want to get rid of those gaps - reset the index - we can do so with the following:
#
# Rob: Note how the old index column is still maintained

# %%
fortune500_df.reset_index(inplace = True)
fortune500_df
# Out:
#        level_0  index  year  rank                company  revenue profit
# 0            0      0  1955     1         General Motors   9823.5    806
# 1            1      1  1955     2            Exxon Mobil   5661.4  584.8
# 2            2      2  1955     3             U.S. Steel   3250.4  195.4
# 3            3      3  1955     4       General Electric   2959.1  212.6
# 4            4      4  1955     5                 Esmark   2510.8   19.1
# ...        ...    ...   ...   ...                    ...      ...    ...
# 25126    25126  25495  2005   496        Wm. Wrigley Jr.   3648.6    493
# 25127    25127  25496  2005   497         Peabody Energy   3631.6  175.4
# 25128    25128  25497  2005   498  Wendy's International   3630.4   57.8
# 25129    25129  25498  2005   499     Kindred Healthcare   3616.6   70.6
# 25130    25130  25499  2005   500   Cincinnati Financial   3614.0    584
#
# [25131 rows x 7 columns]

# %% [markdown]
# Rob: The following is important
#
# Note that we've now created a new index, but we've also created a column "index" that retains the previous index values. So, you don't lose the old index values when you reset.
#
# Sometimes this is great. Other times, it's just another column, and you should probably drop it:

# %%
fortune500_df.drop(columns = ['index'], inplace = True)
fortune500_df
# Out:
# /var/folders/vw/9gqqlzfx5yq6pxkdr2xp20hm0000gn/T/ipykernel_2205/788303630.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fortune500_df.drop(columns = ['index'], inplace = True)
#        level_0  year  rank                company  revenue profit
# 0            0  1955     1         General Motors   9823.5    806
# 1            1  1955     2            Exxon Mobil   5661.4  584.8
# 2            2  1955     3             U.S. Steel   3250.4  195.4
# 3            3  1955     4       General Electric   2959.1  212.6
# 4            4  1955     5                 Esmark   2510.8   19.1
# ...        ...   ...   ...                    ...      ...    ...
# 25126    25126  2005   496        Wm. Wrigley Jr.   3648.6    493
# 25127    25127  2005   497         Peabody Energy   3631.6  175.4
# 25128    25128  2005   498  Wendy's International   3630.4   57.8
# 25129    25129  2005   499     Kindred Healthcare   3616.6   70.6
# 25130    25130  2005   500   Cincinnati Financial   3614.0    584
#
# [25131 rows x 6 columns]

# %% [markdown]
# Now, suppose we wanted to aggregate the values in the dataframe above into individual years. The way we'd do this for, say, revenue is straightforward, but for the companies it's a bit tricky. One way you could do it is by collapsing them all into a list.
#
# Rob: We're adding two additional columns to maintain the list of companies who were in the data by year. Cool example. Could also have been done with a pivot table

# %%
companies_by_year_df = fortune500_df.groupby(by = ['year']).agg(
    company_list = ('company',lambda x: x.tolist()), total_revenue = ('revenue', np.sum))
companies_by_year_df
# Out:
#                                            company_list  total_revenue
# year
# 1955  [General Motors, Exxon Mobil, U.S. Steel, Gene...       136222.7
# 1956  [General Motors, Exxon Mobil, Ford Motor, U.S....       161155.0
# 1957  [General Motors, Exxon Mobil, Ford Motor, U.S....       173968.7
# 1958  [General Motors, Exxon Mobil, Ford Motor, U.S....       187854.7
# 1959  [General Motors, Exxon Mobil, Ford Motor, Gene...       176549.0
# 1960  [General Motors, Exxon Mobil, Ford Motor, Gene...       197220.7
# 1961  [General Motors, Exxon Mobil, Ford Motor, Gene...       204455.1
# 1962  [General Motors, Exxon Mobil, Ford Motor, Gene...       208939.3
# 1963  [General Motors, Exxon Mobil, Ford Motor, Gene...       229082.1
# 1964  [General Motors, Exxon Mobil, Ford Motor, Gene...       245090.8
# 1965  [General Motors, Exxon Mobil, Ford Motor, Gene...       266395.4
# 1966  [General Motors, Ford Motor, Exxon Mobil, Gene...       298059.1
# 1967  [General Motors, Ford Motor, Exxon Mobil, Gene...       332580.4
# 1968  [General Motors, Exxon Mobil, Ford Motor, Gene...       358885.8
# 1969  [General Motors, Exxon Mobil, Ford Motor, Gene...       405273.2
# 1970  [General Motors, Exxon Mobil, Ford Motor, Gene...       444718.2
# 1971  [General Motors, Exxon Mobil, Ford Motor, Gene...       458677.4
# 1972  [General Motors, Exxon Mobil, Ford Motor, Gene...       498823.4
# 1973  [General Motors, Exxon Mobil, Ford Motor, Gene...       553346.2
# 1974  [General Motors, Exxon Mobil, Ford Motor, Chry...       662090.0
# 1975  [Exxon Mobil, General Motors, Ford Motor, Texa...       827219.5
# 1976  [Exxon Mobil, General Motors, Texaco, Ford Mot...       858157.3
# 1977  [Exxon Mobil, General Motors, Ford Motor, Texa...       963232.4
# 1978  [General Motors, Exxon Mobil, Ford Motor, Mobi...      1075697.3
# 1979  [General Motors, Exxon Mobil, Ford Motor, Mobi...      1205852.9
# 1980  [Exxon Mobil, General Motors, Mobil, Ford Moto...      1433378.0
# 1981  [Exxon Mobil, Mobil, General Motors, Texaco, C...      1634583.8
# 1982  [Exxon Mobil, Mobil, General Motors, Texaco, C...      1753244.5
# 1983  [Exxon Mobil, General Motors, Mobil, Texaco, F...      1657645.6
# 1984  [Exxon Mobil, General Motors, Mobil, Ford Moto...      1671259.0
# 1985  [Exxon Mobil, General Motors, Mobil, Ford Moto...      1742985.2
# 1986  [General Motors, Exxon Mobil, Mobil, Ford Moto...      1774417.0
# 1987  [General Motors, Exxon Mobil, Ford Motor, Intl...      1693606.6
# 1988  [General Motors, Exxon Mobil, Ford Motor, Intl...      1838798.0
# 1989  [General Motors, Ford Motor, Exxon Mobil, Intl...      1992367.0
# 1990  [General Motors, Ford Motor, Exxon Mobil, Intl...      2138093.6
# 1991  [General Motors, Exxon Mobil, Ford Motor, Intl...      2274082.0
# 1992  [General Motors, Exxon Mobil, Ford Motor, Intl...      2228353.4
# 1993  [General Motors, Exxon Mobil, Ford Motor, Intl...      2342696.3
# 1994  [General Motors, Ford Motor, Exxon Mobil, Intl...      2345073.3
# 1995  [General Motors, Ford Motor, Exxon Mobil, Wal-...      4247422.7
# 1996  [General Motors, Ford Motor, Exxon Mobil, Wal-...      4665242.4
# 1997  [General Motors, Ford Motor, Exxon Mobil, Wal-...      5048392.0
# 1998  [General Motors, Ford Motor, Exxon Mobil, Wal-...      5503123.6
# 1999  [General Motors, Ford Motor, Wal-Mart Stores, ...      5721879.3
# 2000  [General Motors, Wal-Mart Stores, Exxon Mobil,...      6300133.1
# 2001  [Exxon Mobil, Wal-Mart Stores, General Motors,...      7155910.3
# 2002  [Wal-Mart Stores, Exxon Mobil, General Motors,...      7258518.1
# 2003  [Wal-Mart Stores, General Motors, Exxon Mobil,...      6927772.0
# 2004  [Wal-Mart Stores, Exxon Mobil, General Motors,...      7465268.5
# 2005  [Wal-Mart Stores, Exxon Mobil, General Motors,...      8244202.6

# %% [markdown]
# From here, suppose we wanted to check out the year-over-year revenue change. One way we could do this is by using the "shift" function:
#
# Rob: Super clever function to keep the index the same, but move everything a row down. The dataframe in memory remains the same, it's just a view that is changing.

# %%
companies_by_year_df.shift(1)
# Out:
#                                            company_list  total_revenue  \
# year
# 1996  [General Motors, Ford Motor, Exxon Mobil, Wal-...      4247422.7
# 1997  [General Motors, Ford Motor, Exxon Mobil, Wal-...      4665242.4
# 1998  [General Motors, Ford Motor, Exxon Mobil, Wal-...      5048392.0
# 1999  [General Motors, Ford Motor, Exxon Mobil, Wal-...      5503123.6
# 2000  [General Motors, Ford Motor, Wal-Mart Stores, ...      5721879.3
# 2001  [General Motors, Wal-Mart Stores, Exxon Mobil,...      6300133.1
# 2002  [Exxon Mobil, Wal-Mart Stores, General Motors,...      7155910.3
# 2003  [Wal-Mart Stores, Exxon Mobil, General Motors,...      7258518.1
# 2004  [Wal-Mart Stores, General Motors, Exxon Mobil,...      6927772.0
# 2005  [Wal-Mart Stores, Exxon Mobil, General Motors,...      7465268.5
#
#       change_in_revenue
# year
# 1955                NaN
# 1956                NaN
# 1957            24932.3
# 1958            12813.7
# 1959            13886.0
# 1960           -11305.7
# 1961            20671.7
# 1962             7234.4
# 1963             4484.2
# 1964            20142.8
# 1965            16008.7
# 1966            21304.6
# 1967            31663.7
# 1968            34521.3
# 1969            26305.4
# 1970            46387.4
# 1971            39445.0
# 1972            13959.2
# 1973            40146.0
# 1974            54522.8
# 1975           108743.8
# 1976           165129.5
# 1977            30937.8
# 1978           105075.1
# 1979           112464.9
# 1980           130155.6
# 1981           227525.1
# 1982           201205.8
# 1983           118660.7
# 1984           -95598.9
# 1985            13613.4
# 1986            71726.2
# 1987            31431.8
# 1988           -80810.4
# 1989           145191.4
# 1990           153569.0
# 1991           145726.6
# 1992           135988.4
# 1993           -45728.6
# 1994           114342.9
# 1995             2377.0
# 1996          1902349.4
# 1997           417819.7
# 1998           383149.6
# 1999           454731.6
# 2000           218755.7
# 2001           578253.8
# 2002           855777.2
# 2003           102607.8
# 2004          -330746.1
# 2005           537496.5

# %%
companies_by_year_df['change_in_revenue'] = (companies_by_year_df['total_revenue'] 
                                             - companies_by_year_df.shift(1)['total_revenue'])
companies_by_year_df
# Out:
#                                            company_list  total_revenue  \
# year
# 1955  [General Motors, Exxon Mobil, U.S. Steel, Gene...       136222.7
# 1956  [General Motors, Exxon Mobil, Ford Motor, U.S....       161155.0
# 1957  [General Motors, Exxon Mobil, Ford Motor, U.S....       173968.7
# 1958  [General Motors, Exxon Mobil, Ford Motor, U.S....       187854.7
# 1959  [General Motors, Exxon Mobil, Ford Motor, Gene...       176549.0
# 1960  [General Motors, Exxon Mobil, Ford Motor, Gene...       197220.7
# 1961  [General Motors, Exxon Mobil, Ford Motor, Gene...       204455.1
# 1962  [General Motors, Exxon Mobil, Ford Motor, Gene...       208939.3
# 1963  [General Motors, Exxon Mobil, Ford Motor, Gene...       229082.1
# 1964  [General Motors, Exxon Mobil, Ford Motor, Gene...       245090.8
# 1965  [General Motors, Exxon Mobil, Ford Motor, Gene...       266395.4
# 1966  [General Motors, Ford Motor, Exxon Mobil, Gene...       298059.1
# 1967  [General Motors, Ford Motor, Exxon Mobil, Gene...       332580.4
# 1959           -11305.7
# 1960            20671.7
# 1961             7234.4
# 1962             4484.2
# 1963            20142.8
# 1964            16008.7
# 1965            21304.6
# 1966            31663.7
# 1967            34521.3
# 1968            26305.4
# 1969            46387.4
# 1970            39445.0
# 1971            13959.2
# 1972            40146.0
# 1973            54522.8
# 1974           108743.8
# 1975           165129.5
# 1976            30937.8
# 1977           105075.1
# 1978           112464.9
# 1979           130155.6
# 1980           227525.1
# 1981           201205.8
# 1982           118660.7
# 1983           -95598.9
# 1984            13613.4
# 1985            71726.2
# 1986            31431.8
# 1987           -80810.4
# 1988           145191.4
# 1989           153569.0
# 1990           145726.6
# 1991           135988.4
# 1992           -45728.6
# 1993           114342.9
# 1994             2377.0
# 1995          1902349.4
# 1996           417819.7
# 1997           383149.6
# 1998           454731.6
# 1999           218755.7
# 2000           578253.8
# 2001           855777.2
# 2002           102607.8
# 2003          -330746.1
# 2004           537496.5
# 2005           778934.1

# %% [markdown]
# If we want to view the years with the most negative to most positive changes in revenue, we can do so with the sort_values function.

# %%
# Rob: It doesn't like absolute value in the 'by' operator because that column doesn't exist
companies_by_year_df.sort_values(by=['change_in_revenue'], ascending=False)
# Out:
#                                            company_list  total_revenue  \
# year
# 1995  [General Motors, Ford Motor, Exxon Mobil, Wal-...      4247422.7
# 2001  [Exxon Mobil, Wal-Mart Stores, General Motors,...      7155910.3
# 2005  [Wal-Mart Stores, Exxon Mobil, General Motors,...      8244202.6
# 2000  [General Motors, Wal-Mart Stores, Exxon Mobil,...      6300133.1
# 2004  [Wal-Mart Stores, Exxon Mobil, General Motors,...      7465268.5
# 1998  [General Motors, Ford Motor, Exxon Mobil, Wal-...      5503123.6
# 1996  [General Motors, Ford Motor, Exxon Mobil, Wal-...      4665242.4
# 1997  [General Motors, Ford Motor, Exxon Mobil, Wal-...      5048392.0
# 1980  [Exxon Mobil, General Motors, Mobil, Ford Moto...      1433378.0
# 1999  [General Motors, Ford Motor, Wal-Mart Stores, ...      5721879.3
# 1981  [Exxon Mobil, Mobil, General Motors, Texaco, C...      1634583.8
# 1975  [Exxon Mobil, General Motors, Ford Motor, Texa...       827219.5
# 1989  [General Motors, Ford Motor, Exxon Mobil, Intl...      1992367.0
# 1990  [General Motors, Ford Motor, Exxon Mobil, Intl...      2138093.6
# 1988  [General Motors, Exxon Mobil, Ford Motor, Intl...      1838798.0
# 1991  [General Motors, Exxon Mobil, Ford Motor, Intl...      2274082.0
# 1979  [General Motors, Exxon Mobil, Ford Motor, Mobi...      1205852.9
# 1982  [Exxon Mobil, Mobil, General Motors, Texaco, C...      1753244.5
# 1993  [General Motors, Exxon Mobil, Ford Motor, Intl...      2342696.3
# 1978  [General Motors, Exxon Mobil, Ford Motor, Mobi...      1075697.3
# 1974  [General Motors, Exxon Mobil, Ford Motor, Chry...       662090.0
# 1977  [Exxon Mobil, General Motors, Ford Motor, Texa...       963232.4
# 2002  [Wal-Mart Stores, Exxon Mobil, General Motors,...      7258518.1
# 1959           -11305.7
# 1992           -45728.6
# 1987           -80810.4
# 1983           -95598.9
# 2003          -330746.1
# 1955                NaN

# %% [markdown]
# If we want to unravel our list of companies, we can do so with the "explode" function, which takes a list and returns a bunch of rows, one for each element in the list.

# %%
# Rob: The explode() function will create a new row for every element in the list
companies_by_year_explode_df = companies_by_year_df.explode(column = ['company_list'])
companies_by_year_explode_df
# Out:
#                company_list  total_revenue  change_in_revenue
# year
# 1955         General Motors       136222.7                NaN
# 1955            Exxon Mobil       136222.7                NaN
# 1955             U.S. Steel       136222.7                NaN
# 1955       General Electric       136222.7                NaN
# 1955                 Esmark       136222.7                NaN
# ...                     ...            ...                ...
# 2005        Wm. Wrigley Jr.      8244202.6           778934.1
# 2005         Peabody Energy      8244202.6           778934.1
# 2005  Wendy's International      8244202.6           778934.1
# 2005     Kindred Healthcare      8244202.6           778934.1
# 2005   Cincinnati Financial      8244202.6           778934.1
#
# [25131 rows x 3 columns]

# %% [markdown]
# Here if we wanted to have a unique index we could get one by resetting the index, but this is a nice example of where you might want to hold onto the original index as well.

# %%
companies_by_year_explode_df = companies_by_year_explode_df.reset_index()
companies_by_year_explode_df
# Out:
#        index  year           company_list
# 0          0  1955         General Motors
# 1          1  1955            Exxon Mobil
# 2          2  1955             U.S. Steel
# 3          3  1955       General Electric
# 4          4  1955                 Esmark
# ...      ...   ...                    ...
# 25126  25126  2005        Wm. Wrigley Jr.
# 25127  25127  2005         Peabody Energy
# 25128  25128  2005  Wendy's International
# 25129  25129  2005     Kindred Healthcare
# 25130  25130  2005   Cincinnati Financial
#
# [25131 rows x 3 columns]

# %%
# Rob: Could drop the columns we don't want or we can just mark the columns we want to keep
# Rob: If you have a CSV file with a list of companies that will almost certainly be read in as string and not a Python list. 
# You must convert to a column of lists
companies_by_year_explode_df = companies_by_year_explode_df[['year','company_list']]
companies_by_year_explode_df
# Out:
#        year           company_list
# 0      1955         General Motors
# 1      1955            Exxon Mobil
# 2      1955             U.S. Steel
# 3      1955       General Electric
# 4      1955                 Esmark
# ...     ...                    ...
# 25126  2005        Wm. Wrigley Jr.
# 25127  2005         Peabody Energy
# 25128  2005  Wendy's International
# 25129  2005     Kindred Healthcare
# 25130  2005   Cincinnati Financial
#
# [25131 rows x 2 columns]

# %% [markdown]
# ### Merging

# %% [markdown]
# If you're familiar with SQL, you're probably got some experience merging or "joining" two different tables along a key or set of keys. Well, you can do the same thing in Pandas.
#
# Let's start with a simple example:

# %%
df1 = pd.DataFrame({"key": ["b", "b", "a", "c", "a", "a", "b"], "data1": pd.Series(range(7), dtype = "Int64")})
df2 = pd.DataFrame({"key": ["a", "b", "d"], "data2": pd.Series(range(3), dtype = "Int64")})

# %%
df1
# Out:
#   key  data1
# 0   b      0
# 1   b      1
# 2   a      2
# 3   c      3
# 4   a      4
# 5   a      5
# 6   b      6

# %%
df2
# Out:
#   key  data2
# 0   a      0
# 1   b      1
# 2   d      2

# %% [markdown]
# If we merge these, we get:

# %%
# Rob: Merge is the Pandas version of a SQL join
pd.merge(df1,df2)
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %% [markdown]
# Rob: **Note that I didn't specify which column to join on. If that information is not specified, merge uses the overlapping column names as the keys if it can. It's good practice to specify explicitly - in this case both tables have the key column though:**

# %%
pd.merge(df1,df2, on='key')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %% [markdown]
# If the column names are different in each column you can specify them separately. Rob: Here the fundamental data is the same, but the key column is different

# %%
df3 = pd.DataFrame({"lkey": ["b", "b", "a", "c", "a", "a", "b"], "data1": pd.Series(range(7), dtype = "Int64")})
df4 = pd.DataFrame({"rkey": ["a", "b", "d"], "data2": pd.Series(range(3), dtype = "Int64")})

# %%
# Rob: With different key names, the default join throws an error
pd.merge(df3,df4)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# /Users/robchristiansen/PycharmProjects/Weber State/Data Science Algorithms I/CS-6570 Lecture 5 - Data Wrangling.ipynb Cell 35 in 2
#       <a href='vscode-notebook-cell:/Users/robchristiansen/PycharmProjects/Weber%20State/Data%20Science%20Algorithms%20I/CS-6570%20Lecture%205%20-%20Data%20Wrangling.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> # Rob: With different key names, the default join throws an error
# ----> <a href='vscode-notebook-cell:/Users/robchristiansen/PycharmProjects/Weber%20State/Data%20Science%20Algorithms%20I/CS-6570%20Lecture%205%20-%20Data%20Wrangling.ipynb#X46sZmlsZQ%3D%3D?line=1'>2</a> pd.merge(df3,df4)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/reshape/merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/reshape/merge.py:685, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     681     # stacklevel chosen to be correct when this is reached via pd.merge
#     682     # (and not DataFrame.join)
#     683     warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
# --> 685 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     687 cross_col = None
#     688 if self.how == "cross":
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/reshape/merge.py:1434, in _MergeOperation._validate_left_right_on(self, left_on, right_on)
#    1432 common_cols = left_cols.intersection(right_cols)
#    1433 if len(common_cols) == 0:
# -> 1434     raise MergeError(
#    1435         "No common columns to perform merge on. "
#    1436         f"Merge options: left_on={left_on}, "
#    1437         f"right_on={right_on}, "
#    1438         f"left_index={self.left_index}, "
#    1439         f"right_index={self.right_index}"
#    1440     )
#    1441 if (
#    1442     not left_cols.join(common_cols, how="inner").is_unique
#    1443     or not right_cols.join(common_cols, how="inner").is_unique
#    1444 ):
#    1445     raise MergeError(f"Data columns not unique: {repr(common_cols)}")
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
# Left and right inner joins are also possible using different key names
pd.merge(df3,df4,left_on="lkey", right_on="rkey")
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0

# %%
# Left and right inner joins are also possible using different key names
pd.merge(df3,df4,left_on="lkey", right_on="rkey")
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0

# %%
# Left and right inner joins are also possible using different key names
pd.merge(df3,df4,left_on="lkey", right_on="rkey")
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0

# %%
# Left and right inner joins are also possible using different key names
pd.merge(df3,df4,left_on="lkey", right_on="rkey")
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0

# %% [markdown]
# You may notice the "c" and "d" values and associated data are missing from the result. This is because by default Pandas, like SQL,  does an "inner" join; the keys in the result are the intersection of both tables.
#
# The types of possible joins are:
#
# * "inner" - Use only the key combinations observed in both tables.
# * "left" - Use all key combinations found in the left table.
# * "right" - Use all key combinations found in the right table.
# * "outer" - Use all key combinations found in both tables together.
#
# You can specify the type of join to use with the "how" parameter in a merge call.

# %%
pd.merge(df1,df2, on='key', how="inner")
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
pd.merge(df1,df2, on='key', how="left")
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   a      2      0
# 3   c      3   <NA>
# 4   a      4      0
# 5   a      5      0
# 6   b      6      1

# %%
pd.merge(df1,df2, on='key', how="right")
# Out:
#   key  data1  data2
# 0   a      2      0
# 1   a      4      0
# 2   a      5      0
# 3   b      0      1
# 4   b      1      1
# 5   b      6      1
# 6   d   <NA>      2

# %%
pd.merge(df1,df2, on='key', how="outer")
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0
# 6   c      3   <NA>
# 7   d   <NA>      2

# %% [markdown]
# Rob: In the above example, rows 6 and 7 are in the each of the dataframes.
